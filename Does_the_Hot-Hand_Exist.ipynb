# %% [markdown]
# # Does the "Hot-Hand" in the NBA Truly Exist?

# %% [markdown]
# In this analysis, I explore whether NBA players exhibit the "hot hand" phenomenon—an idea suggesting that a player's chance of making a shot increases after making previous ones. This belief is deeply ingrained in basketball culture, where players are often said to be “on fire” or “in a slump” depending on recent performance.
#
# To test this hypothesis, I use shot-by-shot play-by-play data from the 2024–2025 NBA regular season, pulled directly from the NBA API. Specifically, I examine whether the outcome of a previous field goal attempt (made or missed) has a statistically significant effect on the likelihood of making the next shot.
#
# By applying statistical methods such as chi-square tests and logistic regression, this study aims to determine whether there is meaningful evidence supporting the existence of streak shooting—or if the “hot hand” is merely a cognitive illusion.

# %% [markdown]
# ## Loading Dependencies

# %%
import time
import pandas as pd
from nba_api.stats.endpoints import LeagueGameLog, PlayByPlayV2
from requests.exceptions import ReadTimeout, ConnectionError
from scipy.stats import chi2_contingency
import statsmodels.api as sm

# %% [markdown]
# ## Extracting the data from NBA api

# %%
# Define headers to simulate a browser
headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://www.nba.com",
    "Origin": "https://www.nba.com"
}

# Fetch all regular season game IDs for 2023–24
def get_game_ids():
    print("Fetching game IDs for 2023–24 regular season...")
    games = LeagueGameLog(season='2023-24', season_type_all_star='Regular Season', headers=headers, timeout=60)
    game_log_df = games.get_data_frames()[0]
    return game_log_df['GAME_ID'].unique()

# Fetch play-by-play for a single game with retries
def fetch_pbp(game_id, retries=3, sleep_sec=3):
    for attempt in range(retries):
        try:
            pbp = PlayByPlayV2(game_id=game_id, headers=headers, timeout=60)
            df = pbp.get_data_frames()[0]
            df['GAME_ID'] = game_id
            return df
        except (ReadTimeout, ConnectionError) as e:
            print(f"⚠️ Error fetching Game ID {game_id} (attempt {attempt+1}): {e}")
            time.sleep(sleep_sec * (attempt + 1))  # Exponential backoff
    print(f"❌ Skipped Game ID {game_id} after {retries} attempts")
    return None

# Main loop to fetch all data and write to a single CSV file
def scrape_season_play_by_play_single_file(output_filename="pbp_2023_24_season.csv"):
    game_ids = get_game_ids()
    all_dfs = []

    for i, gid in enumerate(game_ids):
        print(f"[{i+1}/{len(game_ids)}] Processing Game ID: {gid}")
        pbp_df = fetch_pbp(gid)
        if pbp_df is not None:
            all_dfs.append(pbp_df)
        
        # Optional: Print status to keep track of progress
        if (i + 1) % 100 == 0:
            print(f"Progress: {i+1}/{len(game_ids)} games processed.")

    # After all games are processed, concatenate all dataframes
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        combined_df.to_csv(output_filename, index=False)
        print(f"💾 Saved all {len(combined_df)} rows to {output_filename}")
    else:
        print("No data was fetched.")

# Run the script
scrape_season_play_by_play_single_file()
# Out:
# Fetching game IDs for 2023–24 regular season...
# [1/1230] Processing Game ID: 0022300062
# [2/1230] Processing Game ID: 0022300061
# [3/1230] Processing Game ID: 0022300063
# [4/1230] Processing Game ID: 0022300065
# [5/1230] Processing Game ID: 0022300074
# [6/1230] Processing Game ID: 0022300069
# [7/1230] Processing Game ID: 0022300066
# [8/1230] Processing Game ID: 0022300073
# [9/1230] Processing Game ID: 0022300068
# [10/1230] Processing Game ID: 0022300064
# [11/1230] Processing Game ID: 0022300067
# [12/1230] Processing Game ID: 0022300070
# [13/1230] Processing Game ID: 0022300072
# [14/1230] Processing Game ID: 0022300071
# [15/1230] Processing Game ID: 0022300076
# [16/1230] Processing Game ID: 0022300075
# [17/1230] Processing Game ID: 0022300087
# [18/1230] Processing Game ID: 0022300086
# [19/1230] Processing Game ID: 0022300081
# [20/1230] Processing Game ID: 0022300079
# [21/1230] Processing Game ID: 0022300083
# [22/1230] Processing Game ID: 0022300082
# [23/1230] Processing Game ID: 0022300077
# [24/1230] Processing Game ID: 0022300080
# [25/1230] Processing Game ID: 0022300078
# [26/1230] Processing Game ID: 0022300085
# [27/1230] Processing Game ID: 0022300084
# [28/1230] Processing Game ID: 0022300091
# [29/1230] Processing Game ID: 0022300093
# [30/1230] Processing Game ID: 0022300092
# [31/1230] Processing Game ID: 0022300090
# [32/1230] Processing Game ID: 0022300089
# [33/1230] Processing Game ID: 0022300094
# [34/1230] Processing Game ID: 0022300088
# [35/1230] Processing Game ID: 0022300098
# [36/1230] Processing Game ID: 0022300099
# [37/1230] Processing Game ID: 0022300100
# [38/1230] Processing Game ID: 0022300096
# [39/1230] Processing Game ID: 0022300095
# [40/1230] Processing Game ID: 0022300097
# [41/1230] Processing Game ID: 0022300107
# [42/1230] Processing Game ID: 0022300106
# [43/1230] Processing Game ID: 0022300109
# [44/1230] Processing Game ID: 0022300110
# [45/1230] Processing Game ID: 0022300108
# [46/1230] Processing Game ID: 0022300104
# [47/1230] Processing Game ID: 0022300103
# [48/1230] Processing Game ID: 0022300101
# [49/1230] Processing Game ID: 0022300102
# [50/1230] Processing Game ID: 0022300105
# [51/1230] Processing Game ID: 0022300111
# [52/1230] Processing Game ID: 0022300112
# [53/1230] Processing Game ID: 0022300113
# [54/1230] Processing Game ID: 0022300114
# [55/1230] Processing Game ID: 0022300115
# [56/1230] Processing Game ID: 0022300122
# [57/1230] Processing Game ID: 0022300125
# [58/1230] Processing Game ID: 0022300120
# [59/1230] Processing Game ID: 0022300123
# [60/1230] Processing Game ID: 0022300119
# [61/1230] Processing Game ID: 0022300116
# [62/1230] Processing Game ID: 0022300126
# [63/1230] Processing Game ID: 0022300124
# [64/1230] Processing Game ID: 0022300118
# [65/1230] Processing Game ID: 0022300127
# [66/1230] Processing Game ID: 0022300117
# [67/1230] Processing Game ID: 0022300121
# [68/1230] Processing Game ID: 0022300131
# [69/1230] Processing Game ID: 0022300128
# [70/1230] Processing Game ID: 0022300130
# [71/1230] Processing Game ID: 0022300129
# [72/1230] Processing Game ID: 0022300001
# [73/1230] Processing Game ID: 0022300002
# [74/1230] Processing Game ID: 0022300005
# [75/1230] Processing Game ID: 0022300004
# [76/1230] Processing Game ID: 0022300003
# [77/1230] Processing Game ID: 0022300006
# [78/1230] Processing Game ID: 0022300007
# [79/1230] Processing Game ID: 0022300138
# [80/1230] Processing Game ID: 0022300134
# [81/1230] Processing Game ID: 0022300137
# [82/1230] Processing Game ID: 0022300135
# [83/1230] Processing Game ID: 0022300132
# [84/1230] Processing Game ID: 0022300139
# [85/1230] Processing Game ID: 0022300136
# [86/1230] Processing Game ID: 0022300133
# [87/1230] Processing Game ID: 0022300144
# [88/1230] Processing Game ID: 0022300142
# [89/1230] Processing Game ID: 0022300143
# [90/1230] Processing Game ID: 0022300141
# [91/1230] Processing Game ID: 0022300140
# [92/1230] Processing Game ID: 0022300146
# [93/1230] Processing Game ID: 0022300145
# [94/1230] Processing Game ID: 0022300152
# [95/1230] Processing Game ID: 0022300155
# [96/1230] Processing Game ID: 0022300153
# [97/1230] Processing Game ID: 0022300154
# [98/1230] Processing Game ID: 0022300151
# [99/1230] Processing Game ID: 0022300148
# [100/1230] Processing Game ID: 0022300147
# Progress: 100/1230 games processed.
# [101/1230] Processing Game ID: 0022300150
# [102/1230] Processing Game ID: 0022300156
# [103/1230] Processing Game ID: 0022300149
# [104/1230] Processing Game ID: 0022300169
# [105/1230] Processing Game ID: 0022300164
# [106/1230] Processing Game ID: 0022300170
# [107/1230] Processing Game ID: 0022300158
# [108/1230] Processing Game ID: 0022300165
# [109/1230] Processing Game ID: 0022300159
# [110/1230] Processing Game ID: 0022300167
# [111/1230] Processing Game ID: 0022300168
# [112/1230] Processing Game ID: 0022300166
# [113/1230] Processing Game ID: 0022300163
# [114/1230] Processing Game ID: 0022300157
# [115/1230] Processing Game ID: 0022300161
# [116/1230] Processing Game ID: 0022300160
# [117/1230] Processing Game ID: 0022300162
# [118/1230] Processing Game ID: 0022300172
# [119/1230] Processing Game ID: 0022300171
# [120/1230] Processing Game ID: 0022300013
# [121/1230] Processing Game ID: 0022300016
# [122/1230] Processing Game ID: 0022300009
# [123/1230] Processing Game ID: 0022300011
# [124/1230] Processing Game ID: 0022300012
# [125/1230] Processing Game ID: 0022300014
# [126/1230] Processing Game ID: 0022300010
# [127/1230] Processing Game ID: 0022300015
# [128/1230] Processing Game ID: 0022300008
# [129/1230] Processing Game ID: 0022300175
# [130/1230] Processing Game ID: 0022300173
# [131/1230] Processing Game ID: 0022300174
# [132/1230] Processing Game ID: 0022300176
# [133/1230] Processing Game ID: 0022300186
# [134/1230] Processing Game ID: 0022300182
# [135/1230] Processing Game ID: 0022300180
# [136/1230] Processing Game ID: 0022300185
# [137/1230] Processing Game ID: 0022300183
# [138/1230] Processing Game ID: 0022300187
# [139/1230] Processing Game ID: 0022300184
# [140/1230] Processing Game ID: 0022300178
# [141/1230] Processing Game ID: 0022300177
# [142/1230] Processing Game ID: 0022300181
# [143/1230] Processing Game ID: 0022300179
# [144/1230] Processing Game ID: 0022300191
# [145/1230] Processing Game ID: 0022300188
# [146/1230] Processing Game ID: 0022300190
# [147/1230] Processing Game ID: 0022300189
# [148/1230] Processing Game ID: 0022300023
# [149/1230] Processing Game ID: 0022300018
# [150/1230] Processing Game ID: 0022300022
# [151/1230] Processing Game ID: 0022300020
# [152/1230] Processing Game ID: 0022300025
# [153/1230] Processing Game ID: 0022300021
# [154/1230] Processing Game ID: 0022300026
# [155/1230] Processing Game ID: 0022300017
# [156/1230] Processing Game ID: 0022300024
# [157/1230] Processing Game ID: 0022300019
# [158/1230] Processing Game ID: 0022300193
# [159/1230] Processing Game ID: 0022300198
# [160/1230] Processing Game ID: 0022300199
# [161/1230] Processing Game ID: 0022300195
# [162/1230] Processing Game ID: 0022300197
# [163/1230] Processing Game ID: 0022300194
# [164/1230] Processing Game ID: 0022300192
# [165/1230] Processing Game ID: 0022300196
# [166/1230] Processing Game ID: 0022300201
# [167/1230] Processing Game ID: 0022300200
# [168/1230] Processing Game ID: 0022300028
# [169/1230] Processing Game ID: 0022300034
# [170/1230] Processing Game ID: 0022300029
# [171/1230] Processing Game ID: 0022300036
# [172/1230] Processing Game ID: 0022300035
# [173/1230] Processing Game ID: 0022300031
# [174/1230] Processing Game ID: 0022300037
# [175/1230] Processing Game ID: 0022300030
# [176/1230] Processing Game ID: 0022300032
# [177/1230] Processing Game ID: 0022300027
# [178/1230] Processing Game ID: 0022300033
# [179/1230] Processing Game ID: 0022300202
# [180/1230] Processing Game ID: 0022300205
# [181/1230] Processing Game ID: 0022300204
# [182/1230] Processing Game ID: 0022300203
# [183/1230] Processing Game ID: 0022300207
# [184/1230] Processing Game ID: 0022300206
# [185/1230] Processing Game ID: 0022300213
# [186/1230] Processing Game ID: 0022300208
# [187/1230] Processing Game ID: 0022300214
# [188/1230] Processing Game ID: 0022300210
# [189/1230] Processing Game ID: 0022300211
# [190/1230] Processing Game ID: 0022300216
# [191/1230] Processing Game ID: 0022300215
# [192/1230] Processing Game ID: 0022300212
# [193/1230] Processing Game ID: 0022300209
# [194/1230] Processing Game ID: 0022300223
# [195/1230] Processing Game ID: 0022300217
# [196/1230] Processing Game ID: 0022300219
# [197/1230] Processing Game ID: 0022300221
# [198/1230] Processing Game ID: 0022300220
# [199/1230] Processing Game ID: 0022300224
# [200/1230] Processing Game ID: 0022300218
# Progress: 200/1230 games processed.
# [201/1230] Processing Game ID: 0022300222
# [202/1230] Processing Game ID: 0022300039
# [203/1230] Processing Game ID: 0022300040
# [204/1230] Processing Game ID: 0022300038
# [205/1230] Processing Game ID: 0022300042
# [206/1230] Processing Game ID: 0022300041
# [207/1230] Processing Game ID: 0022300229
# [208/1230] Processing Game ID: 0022300235
# [209/1230] Processing Game ID: 0022300236
# [210/1230] Processing Game ID: 0022300228
# [211/1230] Processing Game ID: 0022300227
# [212/1230] Processing Game ID: 0022300232
# [213/1230] Processing Game ID: 0022300237
# [214/1230] Processing Game ID: 0022300234
# [215/1230] Processing Game ID: 0022300233
# [216/1230] Processing Game ID: 0022300226
# [217/1230] Processing Game ID: 0022300230
# [218/1230] Processing Game ID: 0022300238
# [219/1230] Processing Game ID: 0022300225
# [220/1230] Processing Game ID: 0022300231
# [221/1230] Processing Game ID: 0022300048
# [222/1230] Processing Game ID: 0022300049
# [223/1230] Processing Game ID: 0022300052
# [224/1230] Processing Game ID: 0022300044
# [225/1230] Processing Game ID: 0022300047
# [226/1230] Processing Game ID: 0022300043
# [227/1230] Processing Game ID: 0022300050
# [228/1230] Processing Game ID: 0022300046
# [229/1230] Processing Game ID: 0022300051
# [230/1230] Processing Game ID: 0022300045
# [231/1230] Processing Game ID: 0022300242
# [232/1230] Processing Game ID: 0022300241
# [233/1230] Processing Game ID: 0022300239
# [234/1230] Processing Game ID: 0022300244
# [235/1230] Processing Game ID: 0022300240
# [236/1230] Processing Game ID: 0022300243
# [237/1230] Processing Game ID: 0022300252
# [238/1230] Processing Game ID: 0022300248
# [239/1230] Processing Game ID: 0022300245
# [240/1230] Processing Game ID: 0022300249
# [241/1230] Processing Game ID: 0022300251
# [242/1230] Processing Game ID: 0022300247
# [243/1230] Processing Game ID: 0022300250
# [244/1230] Processing Game ID: 0022300246
# [245/1230] Processing Game ID: 0022300257
# [246/1230] Processing Game ID: 0022300253
# [247/1230] Processing Game ID: 0022300256
# [248/1230] Processing Game ID: 0022300255
# [249/1230] Processing Game ID: 0022300254
# [250/1230] Processing Game ID: 0022300055
# [251/1230] Processing Game ID: 0022300057
# [252/1230] Processing Game ID: 0022300058
# [253/1230] Processing Game ID: 0022300059
# [254/1230] Processing Game ID: 0022300054
# [255/1230] Processing Game ID: 0022300060
# [256/1230] Processing Game ID: 0022300053
# [257/1230] Processing Game ID: 0022300056
# [258/1230] Processing Game ID: 0022300259
# [259/1230] Processing Game ID: 0022300261
# [260/1230] Processing Game ID: 0022300260
# [261/1230] Processing Game ID: 0022300258
# [262/1230] Processing Game ID: 0022300264
# [263/1230] Processing Game ID: 0022300263
# [264/1230] Processing Game ID: 0022300262
# [265/1230] Processing Game ID: 0022300271
# [266/1230] Processing Game ID: 0022300267
# [267/1230] Processing Game ID: 0022300268
# [268/1230] Processing Game ID: 0022300266
# [269/1230] Processing Game ID: 0022300265
# [270/1230] Processing Game ID: 0022300270
# [271/1230] Processing Game ID: 0022300272
# [272/1230] Processing Game ID: 0022300273
# [273/1230] Processing Game ID: 0022300269
# [274/1230] Processing Game ID: 0022300278
# [275/1230] Processing Game ID: 0022300274
# [276/1230] Processing Game ID: 0022300279
# [277/1230] Processing Game ID: 0022300277
# [278/1230] Processing Game ID: 0022300275
# [279/1230] Processing Game ID: 0022300276
# [280/1230] Processing Game ID: 0022300282
# [281/1230] Processing Game ID: 0022300291
# [282/1230] Processing Game ID: 0022300288
# [283/1230] Processing Game ID: 0022300289
# [284/1230] Processing Game ID: 0022300280
# [285/1230] Processing Game ID: 0022300287
# [286/1230] Processing Game ID: 0022300285
# [287/1230] Processing Game ID: 0022300286
# [288/1230] Processing Game ID: 0022300290
# [289/1230] Processing Game ID: 0022300283
# [290/1230] Processing Game ID: 0022300281
# [291/1230] Processing Game ID: 0022300284
# [292/1230] Processing Game ID: 0022301202
# [293/1230] Processing Game ID: 0022301204
# [294/1230] Processing Game ID: 0022301203
# [295/1230] Processing Game ID: 0022301201
# [296/1230] Processing Game ID: 0022301206
# [297/1230] Processing Game ID: 0022301205
# [298/1230] Processing Game ID: 0022301208
# [299/1230] Processing Game ID: 0022301207
# [300/1230] Processing Game ID: 0022301213
# Progress: 300/1230 games processed.
# [301/1230] Processing Game ID: 0022301212
# [302/1230] Processing Game ID: 0022301209
# [303/1230] Processing Game ID: 0022301211
# [304/1230] Processing Game ID: 0022301210
# [305/1230] Processing Game ID: 0022301215
# [306/1230] Processing Game ID: 0022301214
# [307/1230] Processing Game ID: 0022301230
# [308/1230] Processing Game ID: 0022301229
# [309/1230] Processing Game ID: 0022301220
# [310/1230] Processing Game ID: 0022301222
# [311/1230] Processing Game ID: 0022301227
# [312/1230] Processing Game ID: 0022301225
# [313/1230] Processing Game ID: 0022301216
# [314/1230] Processing Game ID: 0022301226
# [315/1230] Processing Game ID: 0022301223
# [316/1230] Processing Game ID: 0022301221
# [317/1230] Processing Game ID: 0022301224
# [318/1230] Processing Game ID: 0022301219
# [319/1230] Processing Game ID: 0022301228
# [320/1230] Processing Game ID: 0022301218
# [321/1230] Processing Game ID: 0022301217
# [322/1230] Processing Game ID: 0022300298
# [323/1230] Processing Game ID: 0022300301
# [324/1230] Processing Game ID: 0022300302
# [325/1230] Processing Game ID: 0022300295
# [326/1230] Processing Game ID: 0022300296
# [327/1230] Processing Game ID: 0022300292
# [328/1230] Processing Game ID: 0022300300
# [329/1230] Processing Game ID: 0022300303
# [330/1230] Processing Game ID: 0022300297
# [331/1230] Processing Game ID: 0022300293
# [332/1230] Processing Game ID: 0022300299
# [333/1230] Processing Game ID: 0022300294
# [334/1230] Processing Game ID: 0022300304
# [335/1230] Processing Game ID: 0022300309
# [336/1230] Processing Game ID: 0022300306
# [337/1230] Processing Game ID: 0022300305
# [338/1230] Processing Game ID: 0022300308
# [339/1230] Processing Game ID: 0022300307
# [340/1230] Processing Game ID: 0022300316
# [341/1230] Processing Game ID: 0022300315
# [342/1230] Processing Game ID: 0022300310
# [343/1230] Processing Game ID: 0022300317
# [344/1230] Processing Game ID: 0022300311
# [345/1230] Processing Game ID: 0022300318
# [346/1230] Processing Game ID: 0022300312
# [347/1230] Processing Game ID: 0022300314
# [348/1230] Processing Game ID: 0022300313
# [349/1230] Processing Game ID: 0022300320
# [350/1230] Processing Game ID: 0022300321
# [351/1230] Processing Game ID: 0022300323
# [352/1230] Processing Game ID: 0022300325
# [353/1230] Processing Game ID: 0022300319
# [354/1230] Processing Game ID: 0022300324
# [355/1230] Processing Game ID: 0022300322
# [356/1230] Processing Game ID: 0022300329
# [357/1230] Processing Game ID: 0022300331
# [358/1230] Processing Game ID: 0022300332
# [359/1230] Processing Game ID: 0022300327
# [360/1230] Processing Game ID: 0022300326
# [361/1230] Processing Game ID: 0022300333
# [362/1230] Processing Game ID: 0022300328
# [363/1230] Processing Game ID: 0022300330
# [364/1230] Processing Game ID: 0022300340
# [365/1230] Processing Game ID: 0022300337
# [366/1230] Processing Game ID: 0022300342
# [367/1230] Processing Game ID: 0022300339
# [368/1230] Processing Game ID: 0022300341
# [369/1230] Processing Game ID: 0022300336
# [370/1230] Processing Game ID: 0022300335
# [371/1230] Processing Game ID: 0022300334
# [372/1230] Processing Game ID: 0022300343
# [373/1230] Processing Game ID: 0022300338
# [374/1230] Processing Game ID: 0022300345
# [375/1230] Processing Game ID: 0022300344
# [376/1230] Processing Game ID: 0022300348
# [377/1230] Processing Game ID: 0022300346
# [378/1230] Processing Game ID: 0022300347
# [379/1230] Processing Game ID: 0022300355
# [380/1230] Processing Game ID: 0022300354
# [381/1230] Processing Game ID: 0022300356
# [382/1230] Processing Game ID: 0022300352
# [383/1230] Processing Game ID: 0022300353
# [384/1230] Processing Game ID: 0022300350
# [385/1230] Processing Game ID: 0022300359
# [386/1230] Processing Game ID: 0022300349
# [387/1230] Processing Game ID: 0022300351
# [388/1230] Processing Game ID: 0022300357
# [389/1230] Processing Game ID: 0022300358
# [390/1230] Processing Game ID: 0022300360
# [391/1230] Processing Game ID: 0022300362
# [392/1230] Processing Game ID: 0022300363
# [393/1230] Processing Game ID: 0022300361
# [394/1230] Processing Game ID: 0022300371
# [395/1230] Processing Game ID: 0022300364
# [396/1230] Processing Game ID: 0022300368
# [397/1230] Processing Game ID: 0022300366
# [398/1230] Processing Game ID: 0022300373
# [399/1230] Processing Game ID: 0022300367
# [400/1230] Processing Game ID: 0022300369
# Progress: 400/1230 games processed.
# [401/1230] Processing Game ID: 0022300372
# [402/1230] Processing Game ID: 0022300370
# [403/1230] Processing Game ID: 0022300365
# [404/1230] Processing Game ID: 0022300375
# [405/1230] Processing Game ID: 0022300380
# [406/1230] Processing Game ID: 0022300377
# [407/1230] Processing Game ID: 0022300378
# [408/1230] Processing Game ID: 0022300374
# [409/1230] Processing Game ID: 0022300379
# [410/1230] Processing Game ID: 0022300381
# [411/1230] Processing Game ID: 0022300376
# [412/1230] Processing Game ID: 0022300382
# [413/1230] Processing Game ID: 0022300384
# [414/1230] Processing Game ID: 0022300386
# [415/1230] Processing Game ID: 0022300383
# [416/1230] Processing Game ID: 0022300387
# [417/1230] Processing Game ID: 0022300385
# [418/1230] Processing Game ID: 0022300391
# [419/1230] Processing Game ID: 0022300395
# [420/1230] Processing Game ID: 0022300393
# [421/1230] Processing Game ID: 0022300396
# [422/1230] Processing Game ID: 0022300392
# [423/1230] Processing Game ID: 0022300399
# [424/1230] Processing Game ID: 0022300394
# [425/1230] Processing Game ID: 0022300388
# [426/1230] Processing Game ID: 0022300397
# [427/1230] Processing Game ID: 0022300398
# [428/1230] Processing Game ID: 0022300389
# [429/1230] Processing Game ID: 0022300390
# [430/1230] Processing Game ID: 0022300400
# [431/1230] Processing Game ID: 0022300403
# [432/1230] Processing Game ID: 0022300401
# [433/1230] Processing Game ID: 0022300404
# [434/1230] Processing Game ID: 0022300405
# [435/1230] Processing Game ID: 0022300402
# [436/1230] Processing Game ID: 0022300413
# [437/1230] Processing Game ID: 0022300407
# [438/1230] Processing Game ID: 0022300410
# [439/1230] Processing Game ID: 0022300408
# [440/1230] Processing Game ID: 0022300414
# [441/1230] Processing Game ID: 0022300412
# [442/1230] Processing Game ID: 0022300409
# [443/1230] Processing Game ID: 0022300406
# [444/1230] Processing Game ID: 0022300411
# [445/1230] Processing Game ID: 0022300420
# [446/1230] Processing Game ID: 0022300416
# [447/1230] Processing Game ID: 0022300415
# [448/1230] Processing Game ID: 0022300417
# [449/1230] Processing Game ID: 0022300419
# [450/1230] Processing Game ID: 0022300418
# [451/1230] Processing Game ID: 0022300421
# [452/1230] Processing Game ID: 0022300427
# [453/1230] Processing Game ID: 0022300428
# [454/1230] Processing Game ID: 0022300426
# [455/1230] Processing Game ID: 0022300425
# [456/1230] Processing Game ID: 0022300423
# [457/1230] Processing Game ID: 0022300424
# [458/1230] Processing Game ID: 0022300422
# [459/1230] Processing Game ID: 0022300431
# [460/1230] Processing Game ID: 0022300433
# [461/1230] Processing Game ID: 0022300430
# [462/1230] Processing Game ID: 0022300437
# [463/1230] Processing Game ID: 0022300438
# [464/1230] Processing Game ID: 0022300429
# [465/1230] Processing Game ID: 0022300435
# [466/1230] Processing Game ID: 0022300434
# [467/1230] Processing Game ID: 0022300436
# [468/1230] Processing Game ID: 0022300432
# [469/1230] Processing Game ID: 0022300441
# [470/1230] Processing Game ID: 0022300443
# [471/1230] Processing Game ID: 0022300444
# [472/1230] Processing Game ID: 0022300440
# [473/1230] Processing Game ID: 0022300439
# [474/1230] Processing Game ID: 0022300442
# [475/1230] Processing Game ID: 0022300447
# [476/1230] Processing Game ID: 0022300445
# [477/1230] Processing Game ID: 0022300449
# [478/1230] Processing Game ID: 0022300450
# [479/1230] Processing Game ID: 0022300448
# [480/1230] Processing Game ID: 0022300446
# [481/1230] Processing Game ID: 0022300453
# [482/1230] Processing Game ID: 0022300452
# [483/1230] Processing Game ID: 0022300458
# [484/1230] Processing Game ID: 0022300456
# [485/1230] Processing Game ID: 0022300451
# [486/1230] Processing Game ID: 0022300454
# [487/1230] Processing Game ID: 0022300457
# [488/1230] Processing Game ID: 0022300455
# [489/1230] Processing Game ID: 0022300463
# [490/1230] Processing Game ID: 0022300464
# [491/1230] Processing Game ID: 0022300462
# [492/1230] Processing Game ID: 0022300461
# [493/1230] Processing Game ID: 0022300459
# [494/1230] Processing Game ID: 0022300460
# [495/1230] Processing Game ID: 0022300474
# [496/1230] Processing Game ID: 0022300473
# [497/1230] Processing Game ID: 0022300470
# [498/1230] Processing Game ID: 0022300467
# [499/1230] Processing Game ID: 0022300472
# [500/1230] Processing Game ID: 0022300465
# Progress: 500/1230 games processed.
# [501/1230] Processing Game ID: 0022300469
# [502/1230] Processing Game ID: 0022300476
# [503/1230] Processing Game ID: 0022300468
# [504/1230] Processing Game ID: 0022300475
# [505/1230] Processing Game ID: 0022300471
# [506/1230] Processing Game ID: 0022300466
# [507/1230] Processing Game ID: 0022300477
# [508/1230] Processing Game ID: 0022300478
# [509/1230] Processing Game ID: 0022300482
# [510/1230] Processing Game ID: 0022300487
# [511/1230] Processing Game ID: 0022300485
# [512/1230] Processing Game ID: 0022300484
# [513/1230] Processing Game ID: 0022300481
# [514/1230] Processing Game ID: 0022300492
# [515/1230] Processing Game ID: 0022300479
# [516/1230] Processing Game ID: 0022300489
# [517/1230] Processing Game ID: 0022300491
# [518/1230] Processing Game ID: 0022300490
# [519/1230] Processing Game ID: 0022300488
# [520/1230] Processing Game ID: 0022300486
# [521/1230] Processing Game ID: 0022300483
# [522/1230] Processing Game ID: 0022300480
# [523/1230] Processing Game ID: 0022300495
# [524/1230] Processing Game ID: 0022300496
# [525/1230] Processing Game ID: 0022300493
# [526/1230] Processing Game ID: 0022300494
# [527/1230] Processing Game ID: 0022300505
# [528/1230] Processing Game ID: 0022300497
# [529/1230] Processing Game ID: 0022300499
# [530/1230] Processing Game ID: 0022300503
# [531/1230] Processing Game ID: 0022300504
# [532/1230] Processing Game ID: 0022300500
# [533/1230] Processing Game ID: 0022300501
# [534/1230] Processing Game ID: 0022300498
# [535/1230] Processing Game ID: 0022300502
# [536/1230] Processing Game ID: 0022300509
# [537/1230] Processing Game ID: 0022300511
# [538/1230] Processing Game ID: 0022300510
# [539/1230] Processing Game ID: 0022300506
# [540/1230] Processing Game ID: 0022300508
# [541/1230] Processing Game ID: 0022300507
# [542/1230] Processing Game ID: 0022300512
# [543/1230] Processing Game ID: 0022300515
# [544/1230] Processing Game ID: 0022300516
# [545/1230] Processing Game ID: 0022300514
# [546/1230] Processing Game ID: 0022300513
# [547/1230] Processing Game ID: 0022300526
# [548/1230] Processing Game ID: 0022300522
# [549/1230] Processing Game ID: 0022300517
# [550/1230] Processing Game ID: 0022300521
# [551/1230] Processing Game ID: 0022300519
# [552/1230] Processing Game ID: 0022300518
# [553/1230] Processing Game ID: 0022300523
# [554/1230] Processing Game ID: 0022300524
# [555/1230] Processing Game ID: 0022300520
# [556/1230] Processing Game ID: 0022300525
# [557/1230] Processing Game ID: 0022300528
# [558/1230] Processing Game ID: 0022300531
# [559/1230] Processing Game ID: 0022300529
# [560/1230] Processing Game ID: 0022300527
# [561/1230] Processing Game ID: 0022300530
# [562/1230] Processing Game ID: 0022300541
# [563/1230] Processing Game ID: 0022300537
# [564/1230] Processing Game ID: 0022300535
# [565/1230] Processing Game ID: 0022300540
# [566/1230] Processing Game ID: 0022300534
# [567/1230] Processing Game ID: 0022300533
# [568/1230] Processing Game ID: 0022300532
# [569/1230] Processing Game ID: 0022300536
# [570/1230] Processing Game ID: 0022300538
# [571/1230] Processing Game ID: 0022300539
# [572/1230] Processing Game ID: 0022300548
# [573/1230] Processing Game ID: 0022300545
# [574/1230] Processing Game ID: 0022300542
# [575/1230] Processing Game ID: 0022300546
# [576/1230] Processing Game ID: 0022300543
# [577/1230] Processing Game ID: 0022300544
# [578/1230] Processing Game ID: 0022300547
# [579/1230] Processing Game ID: 0022300549
# [580/1230] Processing Game ID: 0022300550
# [581/1230] Processing Game ID: 0022300552
# [582/1230] Processing Game ID: 0022300554
# [583/1230] Processing Game ID: 0022300553
# [584/1230] Processing Game ID: 0022300551
# [585/1230] Processing Game ID: 0022300557
# [586/1230] Processing Game ID: 0022300561
# [587/1230] Processing Game ID: 0022300563
# [588/1230] Processing Game ID: 0022300558
# [589/1230] Processing Game ID: 0022300556
# [590/1230] Processing Game ID: 0022300559
# [591/1230] Processing Game ID: 0022300564
# [592/1230] Processing Game ID: 0022300562
# [593/1230] Processing Game ID: 0022300565
# [594/1230] Processing Game ID: 0022300555
# [595/1230] Processing Game ID: 0022300560
# [596/1230] Processing Game ID: 0022300568
# [597/1230] Processing Game ID: 0022300566
# [598/1230] Processing Game ID: 0022300567
# [599/1230] Processing Game ID: 0022300577
# [600/1230] Processing Game ID: 0022300578
# Progress: 600/1230 games processed.
# [601/1230] Processing Game ID: 0022300574
# [602/1230] Processing Game ID: 0022300570
# [603/1230] Processing Game ID: 0022300575
# [604/1230] Processing Game ID: 0022300573
# [605/1230] Processing Game ID: 0022300569
# [606/1230] Processing Game ID: 0022300571
# [607/1230] Processing Game ID: 0022300572
# [608/1230] Processing Game ID: 0022300580
# [609/1230] Processing Game ID: 0022300581
# [610/1230] Processing Game ID: 0022300583
# [611/1230] Processing Game ID: 0022300579
# [612/1230] Processing Game ID: 0022300582
# [613/1230] Processing Game ID: 0022300590
# [614/1230] Processing Game ID: 0022300587
# [615/1230] Processing Game ID: 0022300586
# [616/1230] Processing Game ID: 0022300588
# [617/1230] Processing Game ID: 0022300584
# [618/1230] Processing Game ID: 0022300591
# [619/1230] Processing Game ID: 0022300585
# [620/1230] Processing Game ID: 0022300597
# [621/1230] Processing Game ID: 0022300598
# [622/1230] Processing Game ID: 0022300595
# [623/1230] Processing Game ID: 0022300596
# [624/1230] Processing Game ID: 0022300592
# [625/1230] Processing Game ID: 0022300599
# [626/1230] Processing Game ID: 0022300594
# [627/1230] Processing Game ID: 0022300593
# [628/1230] Processing Game ID: 0022300605
# [629/1230] Processing Game ID: 0022300604
# [630/1230] Processing Game ID: 0022300600
# [631/1230] Processing Game ID: 0022300603
# [632/1230] Processing Game ID: 0022300601
# [633/1230] Processing Game ID: 0022300602
# [634/1230] Processing Game ID: 0022300611
# [635/1230] Processing Game ID: 0022300612
# [636/1230] Processing Game ID: 0022300613
# [637/1230] Processing Game ID: 0022300606
# [638/1230] Processing Game ID: 0022300610
# [639/1230] Processing Game ID: 0022300608
# [640/1230] Processing Game ID: 0022300607
# [641/1230] Processing Game ID: 0022300609
# [642/1230] Processing Game ID: 0022300614
# [643/1230] Processing Game ID: 0022300615
# [644/1230] Processing Game ID: 0022300616
# [645/1230] Processing Game ID: 0022300618
# [646/1230] Processing Game ID: 0022300617
# [647/1230] Processing Game ID: 0022300619
# [648/1230] Processing Game ID: 0022300623
# [649/1230] Processing Game ID: 0022300622
# [650/1230] Processing Game ID: 0022300621
# [651/1230] Processing Game ID: 0022300626
# [652/1230] Processing Game ID: 0022300620
# [653/1230] Processing Game ID: 0022300624
# [654/1230] Processing Game ID: 0022300625
# [655/1230] Processing Game ID: 0022300629
# [656/1230] Processing Game ID: 0022300633
# [657/1230] Processing Game ID: 0022300630
# [658/1230] Processing Game ID: 0022300631
# [659/1230] Processing Game ID: 0022300627
# [660/1230] Processing Game ID: 0022300628
# [661/1230] Processing Game ID: 0022300632
# [662/1230] Processing Game ID: 0022300638
# [663/1230] Processing Game ID: 0022300635
# [664/1230] Processing Game ID: 0022300637
# [665/1230] Processing Game ID: 0022300639
# [666/1230] Processing Game ID: 0022300636
# [667/1230] Processing Game ID: 0022300634
# [668/1230] Processing Game ID: 0022300640
# [669/1230] Processing Game ID: 0022300641
# [670/1230] Processing Game ID: 0022300650
# [671/1230] Processing Game ID: 0022300645
# [672/1230] Processing Game ID: 0022300651
# [673/1230] Processing Game ID: 0022300646
# [674/1230] Processing Game ID: 0022300647
# [675/1230] Processing Game ID: 0022300649
# [676/1230] Processing Game ID: 0022300644
# [677/1230] Processing Game ID: 0022300642
# [678/1230] Processing Game ID: 0022300648
# [679/1230] Processing Game ID: 0022300643
# [680/1230] Processing Game ID: 0022300656
# [681/1230] Processing Game ID: 0022300653
# [682/1230] Processing Game ID: 0022300652
# [683/1230] Processing Game ID: 0022300655
# [684/1230] Processing Game ID: 0022300654
# [685/1230] Processing Game ID: 0022300667
# [686/1230] Processing Game ID: 0022300666
# [687/1230] Processing Game ID: 0022300662
# [688/1230] Processing Game ID: 0022300659
# [689/1230] Processing Game ID: 0022300661
# [690/1230] Processing Game ID: 0022300664
# [691/1230] Processing Game ID: 0022300668
# [692/1230] Processing Game ID: 0022300663
# [693/1230] Processing Game ID: 0022300658
# [694/1230] Processing Game ID: 0022300660
# [695/1230] Processing Game ID: 0022300665
# [696/1230] Processing Game ID: 0022300657
# [697/1230] Processing Game ID: 0022300670
# [698/1230] Processing Game ID: 0022300673
# [699/1230] Processing Game ID: 0022300671
# [700/1230] Processing Game ID: 0022300669
# Progress: 700/1230 games processed.
# [701/1230] Processing Game ID: 0022300672
# [702/1230] Processing Game ID: 0022300681
# [703/1230] Processing Game ID: 0022300678
# [704/1230] Processing Game ID: 0022300676
# [705/1230] Processing Game ID: 0022300683
# [706/1230] Processing Game ID: 0022300680
# [707/1230] Processing Game ID: 0022300679
# [708/1230] Processing Game ID: 0022300682
# [709/1230] Processing Game ID: 0022300675
# [710/1230] Processing Game ID: 0022300677
# [711/1230] Processing Game ID: 0022300674
# [712/1230] Processing Game ID: 0022300684
# [713/1230] Processing Game ID: 0022300686
# [714/1230] Processing Game ID: 0022300685
# [715/1230] Processing Game ID: 0022300687
# [716/1230] Processing Game ID: 0022300697
# [717/1230] Processing Game ID: 0022300690
# [718/1230] Processing Game ID: 0022300692
# [719/1230] Processing Game ID: 0022300688
# [720/1230] Processing Game ID: 0022300689
# [721/1230] Processing Game ID: 0022300693
# [722/1230] Processing Game ID: 0022300691
# [723/1230] Processing Game ID: 0022300696
# [724/1230] Processing Game ID: 0022300695
# [725/1230] Processing Game ID: 0022300694
# [726/1230] Processing Game ID: 0022300701
# [727/1230] Processing Game ID: 0022300699
# [728/1230] Processing Game ID: 0022300700
# [729/1230] Processing Game ID: 0022300698
# [730/1230] Processing Game ID: 0022300703
# [731/1230] Processing Game ID: 0022300702
# [732/1230] Processing Game ID: 0022300707
# [733/1230] Processing Game ID: 0022300712
# [734/1230] Processing Game ID: 0022300709
# [735/1230] Processing Game ID: 0022300706
# [736/1230] Processing Game ID: 0022300710
# [737/1230] Processing Game ID: 0022300711
# [738/1230] Processing Game ID: 0022300704
# [739/1230] Processing Game ID: 0022300705
# [740/1230] Processing Game ID: 0022300708
# [741/1230] Processing Game ID: 0022300717
# [742/1230] Processing Game ID: 0022300715
# [743/1230] Processing Game ID: 0022300718
# [744/1230] Processing Game ID: 0022300716
# [745/1230] Processing Game ID: 0022300714
# [746/1230] Processing Game ID: 0022300713
# [747/1230] Processing Game ID: 0022300725
# [748/1230] Processing Game ID: 0022300723
# [749/1230] Processing Game ID: 0022300724
# [750/1230] Processing Game ID: 0022300719
# [751/1230] Processing Game ID: 0022300721
# [752/1230] Processing Game ID: 0022300720
# [753/1230] Processing Game ID: 0022300722
# [754/1230] Processing Game ID: 0022300726
# [755/1230] Processing Game ID: 0022300732
# [756/1230] Processing Game ID: 0022300730
# [757/1230] Processing Game ID: 0022300728
# [758/1230] Processing Game ID: 0022300727
# [759/1230] Processing Game ID: 0022300729
# [760/1230] Processing Game ID: 0022300731
# [761/1230] Processing Game ID: 0022300738
# [762/1230] Processing Game ID: 0022300733
# [763/1230] Processing Game ID: 0022300740
# [764/1230] Processing Game ID: 0022300736
# [765/1230] Processing Game ID: 0022300739
# [766/1230] Processing Game ID: 0022300735
# [767/1230] Processing Game ID: 0022300734
# [768/1230] Processing Game ID: 0022300741
# [769/1230] Processing Game ID: 0022300737
# [770/1230] Processing Game ID: 0022300747
# [771/1230] Processing Game ID: 0022300746
# [772/1230] Processing Game ID: 0022300744
# [773/1230] Processing Game ID: 0022300745
# [774/1230] Processing Game ID: 0022300743
# [775/1230] Processing Game ID: 0022300742
# [776/1230] Processing Game ID: 0022300756
# [777/1230] Processing Game ID: 0022300754
# [778/1230] Processing Game ID: 0022300758
# [779/1230] Processing Game ID: 0022300748
# [780/1230] Processing Game ID: 0022300755
# [781/1230] Processing Game ID: 0022300757
# [782/1230] Processing Game ID: 0022300752
# [783/1230] Processing Game ID: 0022300749
# [784/1230] Processing Game ID: 0022300753
# [785/1230] Processing Game ID: 0022300750
# [786/1230] Processing Game ID: 0022300751
# [787/1230] Processing Game ID: 0022300760
# [788/1230] Processing Game ID: 0022300759
# [789/1230] Processing Game ID: 0022300768
# [790/1230] Processing Game ID: 0022300761
# [791/1230] Processing Game ID: 0022300764
# [792/1230] Processing Game ID: 0022300762
# [793/1230] Processing Game ID: 0022300770
# [794/1230] Processing Game ID: 0022300767
# [795/1230] Processing Game ID: 0022300769
# [796/1230] Processing Game ID: 0022300766
# [797/1230] Processing Game ID: 0022300765
# [798/1230] Processing Game ID: 0022300763
# [799/1230] Processing Game ID: 0022300775
# [800/1230] Processing Game ID: 0022300776
# Progress: 800/1230 games processed.
# [801/1230] Processing Game ID: 0022300772
# [802/1230] Processing Game ID: 0022300773
# [803/1230] Processing Game ID: 0022300771
# [804/1230] Processing Game ID: 0022300774
# [805/1230] Processing Game ID: 0022300783
# [806/1230] Processing Game ID: 0022300777
# [807/1230] Processing Game ID: 0022300788
# [808/1230] Processing Game ID: 0022300778
# [809/1230] Processing Game ID: 0022300782
# [810/1230] Processing Game ID: 0022300785
# [811/1230] Processing Game ID: 0022300784
# [812/1230] Processing Game ID: 0022300781
# [813/1230] Processing Game ID: 0022300787
# [814/1230] Processing Game ID: 0022300786
# [815/1230] Processing Game ID: 0022300789
# [816/1230] Processing Game ID: 0022300780
# [817/1230] Processing Game ID: 0022300779
# [818/1230] Processing Game ID: 0022300576
# [819/1230] Processing Game ID: 0022300790
# [820/1230] Processing Game ID: 0022300791
# [821/1230] Processing Game ID: 0022300796
# [822/1230] Processing Game ID: 0022300793
# [823/1230] Processing Game ID: 0022300803
# [824/1230] Processing Game ID: 0022300794
# [825/1230] Processing Game ID: 0022300798
# [826/1230] Processing Game ID: 0022300802
# [827/1230] Processing Game ID: 0022300795
# [828/1230] Processing Game ID: 0022300792
# [829/1230] Processing Game ID: 0022300801
# [830/1230] Processing Game ID: 0022300800
# [831/1230] Processing Game ID: 0022300797
# [832/1230] Processing Game ID: 0022300799
# [833/1230] Processing Game ID: 0022300806
# [834/1230] Processing Game ID: 0022300811
# [835/1230] Processing Game ID: 0022300810
# [836/1230] Processing Game ID: 0022300813
# [837/1230] Processing Game ID: 0022300809
# [838/1230] Processing Game ID: 0022300808
# [839/1230] Processing Game ID: 0022300804
# [840/1230] Processing Game ID: 0022300807
# [841/1230] Processing Game ID: 0022300805
# [842/1230] Processing Game ID: 0022300812
# [843/1230] Processing Game ID: 0022300814
# [844/1230] Processing Game ID: 0022300815
# [845/1230] Processing Game ID: 0022300816
# [846/1230] Processing Game ID: 0022300827
# [847/1230] Processing Game ID: 0022300820
# [848/1230] Processing Game ID: 0022300822
# [849/1230] Processing Game ID: 0022300825
# [850/1230] Processing Game ID: 0022300818
# [851/1230] Processing Game ID: 0022300823
# [852/1230] Processing Game ID: 0022300824
# [853/1230] Processing Game ID: 0022300821
# [854/1230] Processing Game ID: 0022300817
# [855/1230] Processing Game ID: 0022300826
# [856/1230] Processing Game ID: 0022300819
# [857/1230] Processing Game ID: 0022300829
# [858/1230] Processing Game ID: 0022300831
# [859/1230] Processing Game ID: 0022300828
# [860/1230] Processing Game ID: 0022300830
# [861/1230] Processing Game ID: 0022300842
# [862/1230] Processing Game ID: 0022300832
# [863/1230] Processing Game ID: 0022300838
# [864/1230] Processing Game ID: 0022300835
# [865/1230] Processing Game ID: 0022300834
# [866/1230] Processing Game ID: 0022300833
# [867/1230] Processing Game ID: 0022300841
# [868/1230] Processing Game ID: 0022300839
# [869/1230] Processing Game ID: 0022300837
# [870/1230] Processing Game ID: 0022300836
# [871/1230] Processing Game ID: 0022300840
# [872/1230] Processing Game ID: 0022300846
# [873/1230] Processing Game ID: 0022300847
# [874/1230] Processing Game ID: 0022300845
# [875/1230] Processing Game ID: 0022300843
# [876/1230] Processing Game ID: 0022300844
# [877/1230] Processing Game ID: 0022300848
# [878/1230] Processing Game ID: 0022300850
# [879/1230] Processing Game ID: 0022300854
# [880/1230] Processing Game ID: 0022300852
# [881/1230] Processing Game ID: 0022300849
# [882/1230] Processing Game ID: 0022300851
# [883/1230] Processing Game ID: 0022300856
# [884/1230] Processing Game ID: 0022300855
# [885/1230] Processing Game ID: 0022300853
# [886/1230] Processing Game ID: 0022300860
# [887/1230] Processing Game ID: 0022300859
# [888/1230] Processing Game ID: 0022300857
# [889/1230] Processing Game ID: 0022300865
# [890/1230] Processing Game ID: 0022300861
# [891/1230] Processing Game ID: 0022300864
# [892/1230] Processing Game ID: 0022300858
# [893/1230] Processing Game ID: 0022300863
# [894/1230] Processing Game ID: 0022300862
# [895/1230] Processing Game ID: 0022300869
# [896/1230] Processing Game ID: 0022300870
# [897/1230] Processing Game ID: 0022300866
# [898/1230] Processing Game ID: 0022300868
# [899/1230] Processing Game ID: 0022300867
# [900/1230] Processing Game ID: 0022300874
# Progress: 900/1230 games processed.
# [901/1230] Processing Game ID: 0022300876
# [902/1230] Processing Game ID: 0022300871
# [903/1230] Processing Game ID: 0022300875
# [904/1230] Processing Game ID: 0022300877
# [905/1230] Processing Game ID: 0022300872
# [906/1230] Processing Game ID: 0022300873
# [907/1230] Processing Game ID: 0022300878
# [908/1230] Processing Game ID: 0022300880
# [909/1230] Processing Game ID: 0022300882
# [910/1230] Processing Game ID: 0022300881
# [911/1230] Processing Game ID: 0022300884
# [912/1230] Processing Game ID: 0022300883
# [913/1230] Processing Game ID: 0022300879
# [914/1230] Processing Game ID: 0022300889
# [915/1230] Processing Game ID: 0022300885
# [916/1230] Processing Game ID: 0022300887
# [917/1230] Processing Game ID: 0022300892
# [918/1230] Processing Game ID: 0022300890
# [919/1230] Processing Game ID: 0022300888
# [920/1230] Processing Game ID: 0022300891
# [921/1230] Processing Game ID: 0022300893
# [922/1230] Processing Game ID: 0022300886
# [923/1230] Processing Game ID: 0022300901
# [924/1230] Processing Game ID: 0022300899
# [925/1230] Processing Game ID: 0022300898
# [926/1230] Processing Game ID: 0022300897
# [927/1230] Processing Game ID: 0022300895
# [928/1230] Processing Game ID: 0022300900
# [929/1230] Processing Game ID: 0022300894
# [930/1230] Processing Game ID: 0022300896
# [931/1230] Processing Game ID: 0022300906
# [932/1230] Processing Game ID: 0022300903
# [933/1230] Processing Game ID: 0022300907
# [934/1230] Processing Game ID: 0022300902
# [935/1230] Processing Game ID: 0022300905
# [936/1230] Processing Game ID: 0022300904
# [937/1230] Processing Game ID: 0022300908
# [938/1230] Processing Game ID: 0022300912
# [939/1230] Processing Game ID: 0022300910
# [940/1230] Processing Game ID: 0022300913
# [941/1230] Processing Game ID: 0022300916
# [942/1230] Processing Game ID: 0022300914
# [943/1230] Processing Game ID: 0022300915
# [944/1230] Processing Game ID: 0022300909
# [945/1230] Processing Game ID: 0022300911
# [946/1230] Processing Game ID: 0022300921
# [947/1230] Processing Game ID: 0022300923
# [948/1230] Processing Game ID: 0022300919
# [949/1230] Processing Game ID: 0022300917
# [950/1230] Processing Game ID: 0022300918
# [951/1230] Processing Game ID: 0022300922
# [952/1230] Processing Game ID: 0022300920
# [953/1230] Processing Game ID: 0022300927
# [954/1230] Processing Game ID: 0022300924
# [955/1230] Processing Game ID: 0022300932
# [956/1230] Processing Game ID: 0022300926
# [957/1230] Processing Game ID: 0022300928
# [958/1230] Processing Game ID: 0022300930
# [959/1230] Processing Game ID: 0022300929
# [960/1230] Processing Game ID: 0022300931
# [961/1230] Processing Game ID: 0022300925
# [962/1230] Processing Game ID: 0022300937
# [963/1230] Processing Game ID: 0022300935
# [964/1230] Processing Game ID: 0022300938
# [965/1230] Processing Game ID: 0022300934
# [966/1230] Processing Game ID: 0022300936
# [967/1230] Processing Game ID: 0022300933
# [968/1230] Processing Game ID: 0022300940
# [969/1230] Processing Game ID: 0022300939
# [970/1230] Processing Game ID: 0022300941
# [971/1230] Processing Game ID: 0022300944
# [972/1230] Processing Game ID: 0022300945
# [973/1230] Processing Game ID: 0022300943
# [974/1230] Processing Game ID: 0022300942
# [975/1230] Processing Game ID: 0022300947
# [976/1230] Processing Game ID: 0022300952
# [977/1230] Processing Game ID: 0022300948
# [978/1230] Processing Game ID: 0022300951
# [979/1230] Processing Game ID: 0022300954
# [980/1230] Processing Game ID: 0022300949
# [981/1230] Processing Game ID: 0022300950
# [982/1230] Processing Game ID: 0022300953
# [983/1230] Processing Game ID: 0022300946
# [984/1230] Processing Game ID: 0022300956
# [985/1230] Processing Game ID: 0022300958
# [986/1230] Processing Game ID: 0022300955
# [987/1230] Processing Game ID: 0022300957
# [988/1230] Processing Game ID: 0022300960
# [989/1230] Processing Game ID: 0022300959
# [990/1230] Processing Game ID: 0022300962
# [991/1230] Processing Game ID: 0022300966
# [992/1230] Processing Game ID: 0022300963
# [993/1230] Processing Game ID: 0022300965
# [994/1230] Processing Game ID: 0022300961
# [995/1230] Processing Game ID: 0022300964
# [996/1230] Processing Game ID: 0022300968
# [997/1230] Processing Game ID: 0022300974
# [998/1230] Processing Game ID: 0022300973
# [999/1230] Processing Game ID: 0022300972
# [1000/1230] Processing Game ID: 0022300969
# Progress: 1000/1230 games processed.
# [1001/1230] Processing Game ID: 0022300967
# [1002/1230] Processing Game ID: 0022300970
# [1003/1230] Processing Game ID: 0022300971
# [1004/1230] Processing Game ID: 0022300975
# [1005/1230] Processing Game ID: 0022300976
# [1006/1230] Processing Game ID: 0022300981
# [1007/1230] Processing Game ID: 0022300982
# [1008/1230] Processing Game ID: 0022300979
# [1009/1230] Processing Game ID: 0022300978
# [1010/1230] Processing Game ID: 0022300977
# [1011/1230] Processing Game ID: 0022300980
# [1012/1230] Processing Game ID: 0022300986
# [1013/1230] Processing Game ID: 0022300983
# [1014/1230] Processing Game ID: 0022300984
# [1015/1230] Processing Game ID: 0022300988
# [1016/1230] Processing Game ID: 0022300990
# [1017/1230] Processing Game ID: 0022300985
# [1018/1230] Processing Game ID: 0022300989
# [1019/1230] Processing Game ID: 0022300987
# [1020/1230] Processing Game ID: 0022300994
# [1021/1230] Processing Game ID: 0022300991
# [1022/1230] Processing Game ID: 0022300993
# [1023/1230] Processing Game ID: 0022300992
# [1024/1230] Processing Game ID: 0022300995
# [1025/1230] Processing Game ID: 0022301002
# [1026/1230] Processing Game ID: 0022301001
# [1027/1230] Processing Game ID: 0022300999
# [1028/1230] Processing Game ID: 0022301003
# [1029/1230] Processing Game ID: 0022301000
# [1030/1230] Processing Game ID: 0022300998
# [1031/1230] Processing Game ID: 0022300996
# [1032/1230] Processing Game ID: 0022300997
# [1033/1230] Processing Game ID: 0022301007
# [1034/1230] Processing Game ID: 0022301006
# [1035/1230] Processing Game ID: 0022301009
# [1036/1230] Processing Game ID: 0022301010
# [1037/1230] Processing Game ID: 0022301005
# [1038/1230] Processing Game ID: 0022301004
# [1039/1230] Processing Game ID: 0022301008
# [1040/1230] Processing Game ID: 0022301015
# [1041/1230] Processing Game ID: 0022301012
# [1042/1230] Processing Game ID: 0022301016
# [1043/1230] Processing Game ID: 0022301011
# [1044/1230] Processing Game ID: 0022301014
# [1045/1230] Processing Game ID: 0022301017
# [1046/1230] Processing Game ID: 0022301013
# [1047/1230] Processing Game ID: 0022301018
# [1048/1230] Processing Game ID: 0022301023
# [1049/1230] Processing Game ID: 0022301024
# [1050/1230] Processing Game ID: 0022301022
# [1051/1230] Processing Game ID: 0022301019
# [1052/1230] Processing Game ID: 0022301026
# [1053/1230] Processing Game ID: 0022301020
# [1054/1230] Processing Game ID: 0022301025
# [1055/1230] Processing Game ID: 0022301021
# [1056/1230] Processing Game ID: 0022301030
# [1057/1230] Processing Game ID: 0022301027
# [1058/1230] Processing Game ID: 0022301029
# [1059/1230] Processing Game ID: 0022301031
# [1060/1230] Processing Game ID: 0022301028
# [1061/1230] Processing Game ID: 0022301032
# [1062/1230] Processing Game ID: 0022301040
# [1063/1230] Processing Game ID: 0022301035
# [1064/1230] Processing Game ID: 0022301037
# [1065/1230] Processing Game ID: 0022301034
# [1066/1230] Processing Game ID: 0022301038
# [1067/1230] Processing Game ID: 0022301036
# [1068/1230] Processing Game ID: 0022301041
# [1069/1230] Processing Game ID: 0022301043
# [1070/1230] Processing Game ID: 0022301042
# [1071/1230] Processing Game ID: 0022301039
# [1072/1230] Processing Game ID: 0022301033
# [1073/1230] Processing Game ID: 0022301047
# [1074/1230] Processing Game ID: 0022301046
# [1075/1230] Processing Game ID: 0022301045
# [1076/1230] Processing Game ID: 0022301044
# [1077/1230] Processing Game ID: 0022301048
# [1078/1230] Processing Game ID: 0022301049
# [1079/1230] Processing Game ID: 0022301054
# [1080/1230] Processing Game ID: 0022301053
# [1081/1230] Processing Game ID: 0022301059
# [1082/1230] Processing Game ID: 0022301058
# [1083/1230] Processing Game ID: 0022301056
# [1084/1230] Processing Game ID: 0022301051
# [1085/1230] Processing Game ID: 0022301052
# [1086/1230] Processing Game ID: 0022301055
# [1087/1230] Processing Game ID: 0022301057
# [1088/1230] Processing Game ID: 0022301050
# [1089/1230] Processing Game ID: 0022301060
# [1090/1230] Processing Game ID: 0022301061
# [1091/1230] Processing Game ID: 0022301069
# [1092/1230] Processing Game ID: 0022301072
# [1093/1230] Processing Game ID: 0022301066
# [1094/1230] Processing Game ID: 0022301063
# [1095/1230] Processing Game ID: 0022301064
# [1096/1230] Processing Game ID: 0022301065
# [1097/1230] Processing Game ID: 0022301071
# [1098/1230] Processing Game ID: 0022301070
# [1099/1230] Processing Game ID: 0022301068
# [1100/1230] Processing Game ID: 0022301062
# Progress: 1100/1230 games processed.
# [1101/1230] Processing Game ID: 0022301073
# [1102/1230] Processing Game ID: 0022301067
# [1103/1230] Processing Game ID: 0022301075
# [1104/1230] Processing Game ID: 0022301074
# [1105/1230] Processing Game ID: 0022301076
# [1106/1230] Processing Game ID: 0022301085
# [1107/1230] Processing Game ID: 0022301081
# [1108/1230] Processing Game ID: 0022301077
# [1109/1230] Processing Game ID: 0022301080
# [1110/1230] Processing Game ID: 0022301078
# [1111/1230] Processing Game ID: 0022301084
# [1112/1230] Processing Game ID: 0022301079
# [1113/1230] Processing Game ID: 0022301082
# [1114/1230] Processing Game ID: 0022301086
# [1115/1230] Processing Game ID: 0022301083
# [1116/1230] Processing Game ID: 0022301089
# [1117/1230] Processing Game ID: 0022301092
# [1118/1230] Processing Game ID: 0022301091
# [1119/1230] Processing Game ID: 0022301088
# [1120/1230] Processing Game ID: 0022301090
# [1121/1230] Processing Game ID: 0022301087
# [1122/1230] Processing Game ID: 0022301093
# [1123/1230] Processing Game ID: 0022301099
# [1124/1230] Processing Game ID: 0022301098
# [1125/1230] Processing Game ID: 0022301095
# [1126/1230] Processing Game ID: 0022301101
# [1127/1230] Processing Game ID: 0022301094
# [1128/1230] Processing Game ID: 0022300589
# [1129/1230] Processing Game ID: 0022301096
# [1130/1230] Processing Game ID: 0022301100
# [1131/1230] Processing Game ID: 0022301106
# [1132/1230] Processing Game ID: 0022301110
# [1133/1230] Processing Game ID: 0022301107
# [1134/1230] Processing Game ID: 0022301108
# [1135/1230] Processing Game ID: 0022301104
# [1136/1230] Processing Game ID: 0022301102
# [1137/1230] Processing Game ID: 0022301103
# [1138/1230] Processing Game ID: 0022301109
# [1139/1230] Processing Game ID: 0022301105
# [1140/1230] Processing Game ID: 0022301112
# [1141/1230] Processing Game ID: 0022301124
# [1142/1230] Processing Game ID: 0022301114
# [1143/1230] Processing Game ID: 0022301113
# [1144/1230] Processing Game ID: 0022301111
# [1145/1230] Processing Game ID: 0022301117
# [1146/1230] Processing Game ID: 0022301097
# [1147/1230] Processing Game ID: 0022301115
# ⚠️ Error fetching Game ID 0022301115 (attempt 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [1148/1230] Processing Game ID: 0022301119
# [1149/1230] Processing Game ID: 0022301121
# [1150/1230] Processing Game ID: 0022301123
# [1151/1230] Processing Game ID: 0022301116
# [1152/1230] Processing Game ID: 0022301122
# [1153/1230] Processing Game ID: 0022301126
# [1154/1230] Processing Game ID: 0022301125
# [1155/1230] Processing Game ID: 0022301118
# [1156/1230] Processing Game ID: 0022301120
# [1157/1230] Processing Game ID: 0022301128
# [1158/1230] Processing Game ID: 0022301130
# [1159/1230] Processing Game ID: 0022301129
# [1160/1230] Processing Game ID: 0022301127
# [1161/1230] Processing Game ID: 0022301138
# [1162/1230] Processing Game ID: 0022301140
# [1163/1230] Processing Game ID: 0022301135
# [1164/1230] Processing Game ID: 0022301132
# [1165/1230] Processing Game ID: 0022301141
# [1166/1230] Processing Game ID: 0022301137
# [1167/1230] Processing Game ID: 0022301143
# [1168/1230] Processing Game ID: 0022301142
# [1169/1230] Processing Game ID: 0022301133
# [1170/1230] Processing Game ID: 0022301136
# [1171/1230] Processing Game ID: 0022301131
# [1172/1230] Processing Game ID: 0022301139
# [1173/1230] Processing Game ID: 0022301134
# [1174/1230] Processing Game ID: 0022301154
# [1175/1230] Processing Game ID: 0022301146
# [1176/1230] Processing Game ID: 0022301148
# [1177/1230] Processing Game ID: 0022301147
# [1178/1230] Processing Game ID: 0022301151
# [1179/1230] Processing Game ID: 0022301157
# [1180/1230] Processing Game ID: 0022301153
# [1181/1230] Processing Game ID: 0022301155
# [1182/1230] Processing Game ID: 0022301145
# [1183/1230] Processing Game ID: 0022301149
# [1184/1230] Processing Game ID: 0022301156
# [1185/1230] Processing Game ID: 0022301150
# [1186/1230] Processing Game ID: 0022301152
# [1187/1230] Processing Game ID: 0022301144
# [1188/1230] Processing Game ID: 0022301165
# [1189/1230] Processing Game ID: 0022301158
# [1190/1230] Processing Game ID: 0022301164
# [1191/1230] Processing Game ID: 0022301161
# [1192/1230] Processing Game ID: 0022301159
# [1193/1230] Processing Game ID: 0022301163
# [1194/1230] Processing Game ID: 0022301160
# [1195/1230] Processing Game ID: 0022301162
# [1196/1230] Processing Game ID: 0022301167
# [1197/1230] Processing Game ID: 0022301169
# [1198/1230] Processing Game ID: 0022301166
# [1199/1230] Processing Game ID: 0022301170
# [1200/1230] Processing Game ID: 0022301168
# Progress: 1200/1230 games processed.
# [1201/1230] Processing Game ID: 0022301185
# [1202/1230] Processing Game ID: 0022301172
# [1203/1230] Processing Game ID: 0022301171
# [1204/1230] Processing Game ID: 0022301182
# [1205/1230] Processing Game ID: 0022301178
# [1206/1230] Processing Game ID: 0022301183
# [1207/1230] Processing Game ID: 0022301179
# [1208/1230] Processing Game ID: 0022301177
# [1209/1230] Processing Game ID: 0022301181
# [1210/1230] Processing Game ID: 0022301175
# [1211/1230] Processing Game ID: 0022301173
# [1212/1230] Processing Game ID: 0022301176
# [1213/1230] Processing Game ID: 0022301180
# [1214/1230] Processing Game ID: 0022301174
# [1215/1230] Processing Game ID: 0022301184
# [1216/1230] Processing Game ID: 0022301196
# [1217/1230] Processing Game ID: 0022301199
# [1218/1230] Processing Game ID: 0022301198
# [1219/1230] Processing Game ID: 0022301192
# [1220/1230] Processing Game ID: 0022301200
# [1221/1230] Processing Game ID: 0022301193
# [1222/1230] Processing Game ID: 0022301186
# [1223/1230] Processing Game ID: 0022301187
# [1224/1230] Processing Game ID: 0022301197
# [1225/1230] Processing Game ID: 0022301190
# [1226/1230] Processing Game ID: 0022301188
# [1227/1230] Processing Game ID: 0022301194
# [1228/1230] Processing Game ID: 0022301195
# [1229/1230] Processing Game ID: 0022301191
# [1230/1230] Processing Game ID: 0022301189
# 💾 Saved all 567672 rows to pbp_2023_24_season.csv

# %%
## Import CSV into a dataframe

# CSV file path
csv_file_path = "pbp_2023_24_season.csv"

# Import CSV to DataFrame
pbp_df = pd.read_csv(csv_file_path)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 60)
# Display the first few rows

pbp_df.head(5)
# Out:
#     GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING  \
# 0  22300062         2            12                   0       1     10:12 PM
# 1  22300062         4            10                   0       1     10:12 PM
# 2  22300062         7             2                  63       1     10:12 PM
# 3  22300062         8             4                   0       1     10:13 PM
# 4  22300062         9             1                  98       1     10:13 PM
#
#   PCTIMESTRING                               HOMEDESCRIPTION  \
# 0        12:00                                           NaN
# 1        12:00  Jump Ball Looney vs. Nurkic: Tip to Thompson
# 2        11:50                  MISS Paul 9' Fadeaway Jumper
# 3        11:48                                           NaN
# 4        11:28                                           NaN
#
#                    NEUTRALDESCRIPTION  \
# 0  Start of 1st Period (10:12 PM EST)
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                   VISITORDESCRIPTION  SCORE SCOREMARGIN  \
# 0                                                NaN    NaN         NaN
# 1                                                NaN    NaN         NaN
# 2                                                NaN    NaN         NaN
# 3                       Nurkic REBOUND (Off:0 Def:1)    NaN         NaN
# 4  Nurkic 4' Cutting Layup Shot (2 PTS) (Durant 1...  2 - 0          -2
#
#    PERSON1TYPE  PLAYER1_ID  PLAYER1_NAME  PLAYER1_TEAM_ID PLAYER1_TEAM_CITY  \
# 0            0           0           NaN              NaN               NaN
# 1            4     1626172  Kevon Looney     1.610613e+09      Golden State
# 2            4      101108    Chris Paul     1.610613e+09      Golden State
# 3            5      203994  Jusuf Nurkić     1.610613e+09           Phoenix
# 4            5      203994  Jusuf Nurkić     1.610613e+09           Phoenix
#
#   PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  PERSON2TYPE  PLAYER2_ID  \
# 0                   NaN                       NaN            0           0
# 1              Warriors                       GSW            5      203994
# 2              Warriors                       GSW            0           0
# 3                  Suns                       PHX            0           0
# 4                  Suns                       PHX            5      201142
#
#    PLAYER2_NAME  PLAYER2_TEAM_ID PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  \
# 0           NaN              NaN               NaN                   NaN
# 1  Jusuf Nurkić     1.610613e+09           Phoenix                  Suns
# 2           NaN              NaN               NaN                   NaN
# 3           NaN              NaN               NaN                   NaN
# 4  Kevin Durant     1.610613e+09           Phoenix                  Suns
#
#   PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE  PLAYER3_ID   PLAYER3_NAME  \
# 0                       NaN            0           0            NaN
# 1                       PHX            4      202691  Klay Thompson
# 2                       NaN            0           0            NaN
# 3                       NaN            0           0            NaN
# 4                       PHX            0           0            NaN
#
#    PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0              NaN               NaN                   NaN
# 1     1.610613e+09      Golden State              Warriors
# 2              NaN               NaN                   NaN
# 3              NaN               NaN                   NaN
# 4              NaN               NaN                   NaN
#
#   PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG
# 0                       NaN                     0
# 1                       GSW                     1
# 2                       NaN                     1
# 3                       NaN                     1
# 4                       NaN                     1

# %% [markdown]
# ## Data Description

# %% [markdown]
# ### Key Columns in the Play-by-Play Dataset
#
# There are 34 total columns available in the dataset. Below are some of the **most relevant columns** for this project, along with short descriptions:
#
# #### 📝 Basic Game and Event Info
# - **`GAME_ID`**: Unique identifier for each NBA game.
# - **`EVENTNUM`**: Sequential number of the event within the game.
# - **`EVENTMSGTYPE`**: High-level category of the event (e.g., field goal, rebound, foul).
# - **`EVENTMSGACTIONTYPE`**: More detailed classification of the action (e.g., pull-up jumper, driving dunk).
#
# #### 🕒 Timing Information
# - **`PERIOD`**: The quarter or overtime period (1–4 for regular periods; 5+ for OT).
# - **`WCTIMESTRING`**: Wall clock time when the event occurred.
# - **`PCTIMESTRING`**: Time remaining in the current period.
#
# #### 🏀 Event Descriptions
# - **`HOMEDESCRIPTION`**: Text description of the event from the home team's perspective.
# - **`VISITORDESCRIPTION`**: Text description of the event from the visiting team's perspective.
#
# #### 📊 Score Information
# - **`SCORE`**: The score at the time of the event (format: `home - visitor`).
# - **`SCOREMARGIN`**: Point margin for the home team (positive = home team leading).
#
# #### 👤 Player & Team Info
# - **`PLAYER1_NAME`**: Name of the main player involved in the event.
# - **`PLAYER1_TEAM_ID`** / **`PLAYER1_TEAM_CITY`**: ID and city of that player's team.
# - **`PLAYER2_NAME`**, **`PLAYER2_TEAM_ID`**, **`PLAYER2_TEAM_CITY`**: Info for a second involved player, if applicable.
#
# ---
#
# ### `EVENTMSGTYPE` Values
#
# To interpret the type of each event, here's a lookup table (based on the [NBA API docs](https://github.com/swar/nba_api/blob/master/docs/examples/PlayByPlay.ipynb)):
#
# | `EVENTMSGTYPE` | Description        |
# |----------------|--------------------|
# | 1              | Field Goal Made     |
# | 2              | Field Goal Missed   |
# | 3              | Free Throw Attempt  |
# | 4              | Rebound             |
# | 5              | Turnover            |
# | 6              | Foul                |
# | 7              | Violation           |
# | 8              | Substitution        |
# | 9              | Timeout             |
# | 10             | Jump Ball           |
# | 11             | Ejection            |
# | 12             | Period Begin        |
# | 13             | Period End          |
# | 18             | Instant Replay      |
#
# > ℹ️ You'll notice the full list ranges from 1 to 18, though not all values may appear in a single game.
#
# ---
#
# ### Understanding `EVENTMSGACTIONTYPE` Values
#
# Below is a categorized breakdown of NBA shot types and their corresponding `EVENTMSGACTIONTYPE` codes. These help describe the specific kind of shot or move attempted.
#
# ---
#
# #### 🏀 3-Point Shots
#
# | Code | Description                                 |
# |------|---------------------------------------------|
# | 1    | 3PT Jump Shot                               |
# | 2    | 3PT Running Jump Shot                       |
# | 3    | Hook Shot                                   |
# | 47   | 3PT Turnaround Jump Shot                    |
# | 63   | 3PT Fadeaway Jumper                         |
# | 66   | 3PT Jump Bank Shot                          |
# | 78   | 3PT Floating Jump Shot                      |
# | 79   | 3PT Pullup Jump Shot                        |
# | 80   | 3PT Step Back Jump Shot                     |
# | 83   | 3PT Fadeaway Bank Shot                      |
# | 85   | 3PT Turnaround Bank Shot                    |
# | 86   | 3PT Turnaround Fadeaway / Shot              |
# | 101  | 3PT Driving Floating Jump Shot              |
# | 102  | 3PT Driving Floating Bank Jump Shot         |
# | 103  | 3PT Running Pull                            |
# | 104  | 3PT Step Back Bank Jump Shot                |
# | 105  | 3PT Turnaround Fadeaway Bank Jump Shot      |
#
# ---
#
# #### 💥 Dunks
#
# | Code | Description                     |
# |------|---------------------------------|
# | 7    | Dunk                            |
# | 9    | Driving Dunk                    |
# | 50   | Running Dunk                    |
# | 51   | Reverse Dunk                    |
# | 52   | Alley-Oop Dunk                  |
# | 87   | Putback Dunk                    |
# | 106  | Running Alley-Oop Dunk Shot     |
# | 109  | Driving Reverse Dunk Shot       |
# | 110  | Running Reverse Dunk Shot       |
#
# ---
#
# #### 🖐️ Layups & Finger Rolls
#
# | Code | Description                         |
# |------|-------------------------------------|
# | 5    | Layup                               |
# | 6    | Driving Layup                       |
# | 41   | Running Layup                       |
# | 43   | Alley-Oop Layup                     |
# | 44   | Reverse Layup                       |
# | 71   | Finger Roll Layup                   |
# | 72   | Putback Layup                       |
# | 73   | Driving Reverse Layup               |
# | 74   | Running Reverse Layup               |
# | 75   | Driving Finger Roll Layup           |
# | 76   | Running Finger Roll Layup           |
# | 98   | Cutting Layup Shot                  |
# | 99   | Cutting Finger Roll Layup Shot      |
# | 100  | Running Alley-Oop Layup Shot        |
# | 97   | Tip Layup Shot                      |
#
# ---
#
# #### ⛹️‍♂️ Jumpers
#
# | Code | Description                               |
# |------|-------------------------------------------|
# | 1    | Jump Shot                                 |
# | 2    | Running Jump Shot                         |
# | 47   | Turnaround Jump Shot                      |
# | 63   | Fadeaway Jumper                           |
# | 66   | Jump Bank Shot                            |
# | 78   | Floating Jump Shot                        |
# | 79   | Pullup Jump Shot                          |
# | 80   | Step Back Jump Shot                       |
# | 83   | Fadeaway Bank Shot                        |
# | 85   | Turnaround Bank Shot                      |
# | 86   | Turnaround Fadeaway                       |
# | 104  | Step Back Bank Jump Shot                  |
# | 105  | Turnaround Fadeaway Bank Jump Shot        |
#
# ---
#
# #### 🌀 Hook Shots
#
# | Code | Description                     |
# |------|---------------------------------|
# | 3    | Hook Shot                       |
# | 57   | Driving Hook Shot               |
# | 58   | Turnaround Hook Shot            |
# | 67   | Hook Bank Shot                  |
# | 93   | Driving Bank Hook Shot          |
# | 96   | Turnaround Bank Hook Shot       |
#
# ---
#
# #### 🏃‍♂️ Movement-Based Shots
#
# | Code | Description                             |
# |------|-----------------------------------------|
# | 98   | Cutting Layup Shot                      |
# | 99   | Cutting Finger Roll Layup Shot          |
# | 103  | Running Pull                            |
# | 106  | Running Alley-Oop Dunk Shot             |
# | 100  | Running Alley-Oop Layup Shot            |
#
# ---
#
# > 📌 Note: Many action types can be both 2-point or 3-point, depending on court location. For example, `Jump Shot (1)` might be a 2-pointer or 3-pointer based on distance.
# > These will help to filter out certain shots that we do not want for our analysis

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### 🧹 Data Cleaning: Preparing the Dataset for Analysis
#
# Before conducting any statistical modeling or hypothesis testing, it's essential to refine the dataset to ensure we are analyzing only the most relevant and comparable shot attempts. `EVENTMSGTYPE` & `EVENTMSGACTIONTYPE` will be critical columns for this cleaning process. Below is a summary of the cleaning steps we will take:
#
# ---
#
# ### 🎯 Key Cleaning Objectives
#
# 1. **Reduce the number of columns** to retain only those that are necessary for our analysis (e.g., player, shot type, time, result).
# 2. **Remove shot attempts that were blocked** — since these are often heavily defended and not representative of a typical jump shot.
# 3. **Exclude fouled shot attempts**, which may result in free throws or affect the outcome in non-random ways.
# 4. **Filter for only Field Goal attempts**:
#    - Keep rows where `EVENTMSGTYPE` is either `1` (Field Goal Made) or `2` (Field Goal Missed).
#    - Remove all other play types such as free throws, rebounds, and fouls.
#
#
# ---
#
# ### 🔍 What Counts as a "Shot" in This Study?
#
# For the purposes of exploring patterns in shooting performance—especially relationships between previous and current shot outcomes—we focus exclusively on **jump shots**.
#
#    We will **exclude non-jump** shot attempts like:
#    - Layups
#    - Dunks
#    - Hook shots
#    - Tip-ins
#
# These shots differ significantly in terms of:
# - **Shot mechanics**
# - **Defensive pressure**
# - **Distance from the basket**
#
# As such, these are considered *outliers* relative to standard jump shots and are removed to improve the consistency and interpretability of the analysis.
#
# ---
#
# By applying these cleaning steps, we aim to construct a dataset that reflects consistent and comparable jump shot attempts, giving us a more accurate basis for testing hot hand effects and other shooting dynamics.

# %% [markdown]
# ### Remove Uneccesary Columns

# %%
columns_to_keep = [
    'GAME_ID',
    'EVENTNUM',
    'EVENTMSGTYPE',
    'EVENTMSGACTIONTYPE',
    'PERIOD',
    'SCORE',
    'SCOREMARGIN',
    'PLAYER1_NAME',   # Player who took the shot
    'PLAYER1_TEAM_ABBREVIATION',
    'HOMEDESCRIPTION', 
    'VISITORDESCRIPTION',
    'PLAYER2_NAME'    # Player2 might refer to the player involved in the event, like a block
]

# Filter the DataFrame to keep only necessary columns
pbp_df = pbp_df[columns_to_keep]

# %% [markdown]
# ### Filter out Blocked Shot Attempts

# %%
# Filter out rows where either 'HOMEDESCRIPTION' or 'VISITORDESCRIPTION' contains the word 'BLOCK'
pbp_df = pbp_df[~pbp_df['HOMEDESCRIPTION'].str.contains('BLOCK', na=False) & 
                                         ~pbp_df['VISITORDESCRIPTION'].str.contains('BLOCK', na=False)]

# %% [markdown]
# ### Filter out Fouled Shot Attempts

# %%
# Filter out rows where either 'HOMEDESCRIPTION' or 'VISITORDESCRIPTION' contains the word 'FOUL'
pbp_df = pbp_df[~pbp_df['HOMEDESCRIPTION'].str.contains('FOUL', na=False) & 
                ~pbp_df['VISITORDESCRIPTION'].str.contains('FOUL', na=False)]

# %% [markdown]
# ### Filter for only Field Goal Attempts

# %%
pbp_df = pbp_df[pbp_df['EVENTMSGTYPE'].isin([1, 2])]

# %% [markdown]
# ### Filter for only Jumpshots

# %%
# Define Which Shot types will be used for our problem
JUMP_SHOT_ACTION_TYPES = {
    1,    # JUMP_SHOT
    2,    # RUNNING_JUMP_SHOT
    63,   # FADEAWAY_JUMPER
    66,   # JUMP_BANK_SHOT
    78,   # FLOATING_JUMP_SHOT
    79,   # PULLUP_JUMP_SHOT
    80,   # STEP_BACK_JUMP_SHOT
    101,  # DRIVING_FLOATING_JUMP_SHOT
    102,  # DRIVING_FLOATING_BANK_JUMP_SHOT
    103,  # RUNNING_PULL
    104,  # STEP_BACK_BANK_JUMP_SHOT
    105,  # TURNAROUND_FADEAWAY_BANK_JUMP_SHOT
    47,   # TURNAROUND_JUMP_SHOT
    86,   # TURNAROUND_FADEAWAY
    85,   # TURNAROUND_BANK_SHOT
    83   # FADEAWAY_BANK_SHOT
    
}
# Filter for jump shots
pbp_df = pbp_df[pbp_df['EVENTMSGACTIONTYPE'].isin(JUMP_SHOT_ACTION_TYPES)].copy()

# %% [markdown]
# ## Creating our X and Y columns

# %%
df = pbp_df.copy()
# Step 1: Create the "Shot Made" column
df['Shot Made'] = df['EVENTMSGTYPE'].apply(lambda x: 1 if x == 1 else 0)

# Step 2: Create "Prev Shot Made" column (Previous shot made for the same player in the same game)
df['Prev Shot Made'] = df.groupby(['GAME_ID', 'PLAYER1_NAME'])['Shot Made'].shift(1)

# Drop rows where "Prev Shot Made" is NaN
df = df.dropna(subset=['Prev Shot Made'])

# Check the results
df[['GAME_ID', 'EVENTNUM', 'PLAYER1_NAME', 'Shot Made', 'Prev Shot Made']]
# Out:
#          GAME_ID  EVENTNUM    PLAYER1_NAME  Shot Made  Prev Shot Made
# 17      22300062        28    Kevin Durant          1             0.0
# 18      22300062        30      Chris Paul          0             0.0
# 22      22300062        34    Devin Booker          1             1.0
# 23      22300062        36   Stephen Curry          0             1.0
# 25      22300062        38    Devin Booker          1             1.0
# ...          ...       ...             ...        ...             ...
# 567631  22301189       592    Delon Wright          0             0.0
# 567633  22301189       594    Jordan Nwora          0             1.0
# 567644  22301189       610    Jordan Nwora          0             0.0
# 567647  22301189       613     Patty Mills          0             0.0
# 567669  22301189       642  Garrett Temple          0             1.0
#
# [113717 rows x 5 columns]

# %% [markdown]
# ## Statistical Tests

# %% [markdown]
# ### Chi-Squared

# %%
df_clean = df.copy()

# Now create the contingency table for the chi-square test
contingency_table = pd.crosstab(df_clean['Prev Shot Made'], df_clean['Shot Made'])

# Perform the Chi-Square test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the result
print(f'Chi-Square Statistic: {chi2}')
print(f'p-value: {p}')
print(f'Degrees of Freedom: {dof}')
print(f'Expected Counts: \n{expected}')

# Interpret the result
alpha = 0.05  # Common significance level
if p < alpha:
    print("The test suggests that the previous shot made and the current shot made are dependent.")
else:
    print("The test suggests that the previous shot made and the current shot made are independent.")
# Out:
# Chi-Square Statistic: 7.086459274716587
# p-value: 0.0077668547859172
# Degrees of Freedom: 1
# Expected Counts:
# [[39234.01864277 26791.98135723]
#  [28338.98135723 19352.01864277]]
# The test suggests that the previous shot made and the current shot made are dependent.

# %% [markdown]
# ### Basic Logistic Model

# %%
# Create a logistic regression model
X = df_clean[['Prev Shot Made']]  # Predictor (previous shot outcome)
X = sm.add_constant(X)  # Add an intercept
y = df_clean['Shot Made']  # Target variable (current shot outcome)

model = sm.Logit(y, X)
result = model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.675254
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Shot Made   No. Observations:               113717
# Model:                          Logit   Df Residuals:                   113715
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 27 May 2025   Pseudo R-squ.:               4.637e-05
# Time:                        16:42:40   Log-Likelihood:                -76788.
# converged:                       True   LL-Null:                       -76791.
# Covariance Type:            nonrobust   LLR p-value:                  0.007616
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.3678      0.008    -46.462      0.000      -0.383      -0.352
# Prev Shot Made    -0.0327      0.012     -2.668      0.008      -0.057      -0.009
# ==================================================================================

# %% [markdown]
# ### Conditional Probabilities

# %%
cond_probs = df_clean.groupby('Prev Shot Made')['Shot Made'].mean()
print(cond_probs)
# Out:
# Prev Shot Made
# 0.0    0.409081
# 1.0    0.401208
# Name: Shot Made, dtype: float64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Results Next Steps
#
# The results of my initial analysis suggest that while the effect of the previous shot outcome on the current shot being made is statistically significant, the **magnitude of this effect is minimal**. The coefficient for the previous shot made variable in the logistic regression is negative and small, and the model’s pseudo R² value is virtually zero. This indicates that although there may be some dependency between successive shots, this relationship **explains almost none of the variation** in shot outcomes.
#
# This finding is somewhat surprising to me, especially given my personal belief in the existence of the "hot hand" phenomenon. Intuitively, we often perceive players to go on streaks—making multiple shots in a row—suggesting a temporary boost in performance or confidence. Yet the data, at this level of analysis, appear to contradict that narrative.
#
# However, this discrepancy between perception and statistical evidence has been a well-documented tension in previous research, and it likely stems from the **high degree of variability in shot outcomes**. Factors such as shot distance, defensive pressure, game context, and individual shooting style introduce a significant amount of noise that may obscure more subtle sequential patterns. Without accounting for these confounding variables, it becomes difficult to isolate the true effect of a prior shot on subsequent performance.
#
# ---
#
# ### Improving the Model
#
# Given the size of the dataset, I believe there is an opportunity to refine the analysis by **reducing variation and improving control variables**. A more targeted approach could yield more meaningful insights. For instance, a promising direction would be to:
#
# - **Narrow the analysis to specific shot types**, such as pull-up three-pointers, where mechanics and decision-making are more consistent.
# - **Limit the player sample** to those who attempt a high volume of three-pointers per game (e.g., at least 5 attempts per game). This would reduce inter-player variability and focus the analysis on players more likely to exhibit streaky behavior.
# - **Include more contextual variables**, such as time remaining on the shot clock, game quarter, or score differential, which could affect shot quality and decision-making.
# - **Incorporate player fixed effects** in the model to control for individual shooting tendencies and ability. This would allow the model to focus on within-player variation rather than being dominated by differences between players.
# - Consider using **sequence-based models**, such as Markov chains or hidden Markov models, which may be better suited to capturing streaky behavior and underlying "hot" or "cold" shooting states.
#
# ---
#
# ### Final Thoughts
#
# In sum, the current analysis suggests that the hot hand effect is not strongly supported by a simple logistic regression using all shot types and players. However, this does not rule out its existence. Instead, it highlights the importance of controlling for **context and player-level effects** in uncovering more nuanced performance patterns. Future work will focus on refining the dataset and model to better account for variability and test the hot hand hypothesis under more controlled and realistic conditions.
